# %%
import os
os.listdir('superfish_screenshot_dataset_2/superfish_screenshot_dataset/')
# Out:
# ['screenshots0000_3180',
#  'screenshots0000_3183',
#  'screenshots0000_3179',
#  'screenshots0000_3184',
#  'screenshots0000_3186',
#  'screenshots0000_3181',
#  'screenshots0000_3185',
#  'screenshots0000_3178',
#  'screenshots0000_3182']

# %%
os.getcwd()
# Out:
# '/BystrovA'

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.8/dist-packages (1.5.1)

# %%
import torch
import numpy as np
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import datasets
from torchvision import transforms
from torch import nn
from torch.nn import functional as F
import random
import torchvision.utils as vutils
import argparse
import math
import cv2
from matplotlib import pyplot as plt

from torchsummary import summary

from abc import abstractmethod

# Root directory for dataset
# dataroot = "fish_screenshots_test/"
dataroot = "superfish_screenshot_dataset_2/superfish_screenshot_dataset/"

# Number of workers for dataloader
workers = 2

# Batch size during training
batch_size = 256

# Spatial size of training images. All images will be resized to this
#   size using a transformer.
image_size = 64

embedding_image_size = 4

# Number of channels in the training images. For color images this is 3
in_channels = 1

# Size of z latent vector
nz = 100

# Number of training epochs
num_epochs = 50 # Original is 5 on a dataset of 1 million

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparam for Adam optimizers
beta1 = 0.5

# Number of GPUs available. Use 0 for CPU mode.
ngpu = 3

num_training_updates = 15000

num_hiddens = 64

embedding_dim = 64
num_embeddings = 256

commitment_cost = 0.25
vq_coef = 0

decay = 0.99

learning_rate = 1e-3

num_channels = 1


entropy_weight = 10
kld_weight = 0.00025

# %%
# Set random seed for reproducibility
seed = 1141
# seed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", seed)
random.seed(seed)
torch.manual_seed(seed)
# Out:
# Random Seed:  1141

# %%
class EdgesDataset(datasets.ImageFolder):
  def __init__(self, root, dim, is_valid_file=None):
    super(EdgesDataset, self).__init__(root=root, is_valid_file=is_valid_file)
    self.dim = dim

  def __getitem__(self, index):
    image_path, target = self.samples[index]
    
    # do your magic here
    img = cv2.imread(image_path)
    img = img[32:-32, 32:-32]
    img = cv2.resize(img, self.dim)
    img = cv2.Canny(img,150,250)
    # you need to convert img from np.array to torch.tensor
    # this has to be done CAREFULLY!
    sample = transforms.ToTensor()(img)
    return sample, target

# %%
train_ds = ImageFolder(
    root=dataroot,
#     dim=[image_size,image_size]
    transform = transforms.Compose([transforms.CenterCrop([600-64,800-64]),
                               transforms.Resize([image_size,image_size]),
                               transforms.CenterCrop(image_size),
                               transforms.Grayscale(num_output_channels=1),
                               transforms.ToTensor(),])
)

dataloader = DataLoader(train_ds, batch_size, shuffle=True)

# %%
train_ds = EdgesDataset(
    root=dataroot,
    dim=[image_size,image_size]
#     transform = transforms.Compose([transforms.CenterCrop([600-64,800-64]),
#                                transforms.Resize([image_size,image_size]),
#                                transforms.CenterCrop(image_size),
#                                transforms.ToTensor(),])
)

dataloader = DataLoader(train_ds, batch_size, shuffle=True)

# %%
var = []
i = 0
for batch in dataloader:
    var.append(torch.var(batch[0]))
    i+=1
    if i > 30:
        print('break')
        break
# Out:
# break

# %%
# data_variance = 0.03357546404004097

# %%
data_variance  = sum(var) / len(var)
data_variance = data_variance.item()
data_variance
# Out:
# 0.08209143579006195

# %%
true_percent = []
i = 0
for batch in dataloader:
    
    true_percent.append(torch.count_nonzero(batch[0]) / image_size ** 2 / batch_size)
    i+=1
    if i > 30:
        print('break')
        break
# Out:
# break

# %%
true_percentage  = sum(true_percent) / len(true_percent)
true_percentage = true_percentage.item()
true_percentage
# Out:
# 0.0896645188331604

# %%
# Decide which device we want to run on
device = torch.device("cuda:9" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(device)
# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(16, 16))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)).numpy())
# Out:
# cuda:9

# %%
next(iter(dataloader))[0].shape
# Out:
# torch.Size([256, 1, 64, 64])

# %%
def calc_same_pad(i: int, k: int, s: int, d: int) -> int:
    return max((math.ceil(i / s) - 1) * s + (k - 1) * d + 1 - i, 0)

class Conv2dSame(torch.nn.Conv2d):

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        
#         print(x.size())
        ih, iw = x.size()[-2:]

        pad_h = calc_same_pad(i=ih, k=self.kernel_size[0], s=self.stride[0], d=self.dilation[0])
        pad_w = calc_same_pad(i=iw, k=self.kernel_size[1], s=self.stride[1], d=self.dilation[1])
        
        if pad_h > 0 or pad_w > 0:
            x = F.pad(
                x, [pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2]
            )
            
        x = F.conv2d(
            x,
            self.weight,
            self.bias,
            self.stride,
            self.padding,
            self.dilation,
            self.groups,
        )
        
        return x
    
class ConvTranspose2dSame(torch.nn.ConvTranspose2d):

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        
        ih, iw = x.size()[-2:]
        ih *= 2
        iw *= 2

        pad_h = calc_same_pad(i=ih, k=self.kernel_size[0], s=self.stride[0], d=self.dilation[0])
        pad_w = calc_same_pad(i=iw, k=self.kernel_size[1], s=self.stride[1], d=self.dilation[1])
        
        x = F.conv_transpose2d(
            x,
            self.weight,
            self.bias,
            self.stride,
            self.padding,
            self.dilation,
            self.groups,
        )
        
        if pad_h > 0 or pad_w > 0:
            x = F.pad(
                x, list(map(lambda x: -x * self.stride[0], [pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2]))
            )
            
        return x

# %%
def power_calc(number, base):
    power = 0
    
    if (number < 1):
        raise ValueError(f'not power of {base}')
        
    while (number != 1):
            if (number % base != 0):
                raise ValueError(f'not power of {base}')
            number = number // base
            power += 1
             
    return power

# %%
power_calc(128,2)
# Out:
# 7

# %%
list(reversed(np.arange(1,4)))
# Out:
# [3, 2, 1]

# %%
class Encoder(nn.Module):
    def __init__(self, in_channels, num_hiddens, embedding_dim, image_size, embedding_image_size):
        super(Encoder, self).__init__()
        
        num_of_convs = power_calc(image_size,2) - power_calc(embedding_image_size,2)
        
        conv_layers = [Conv2dSame(in_channels=in_channels,
                                 out_channels=num_hiddens // 2**(num_of_convs - 1),
                                 kernel_size=3,
                                 stride=2), 
                       nn.BatchNorm2d(num_hiddens // 2**(num_of_convs - 1)),
                       nn.LeakyReLU()]
        
        for i in reversed(range(1, num_of_convs)):
            conv_layers.append(Conv2dSame(in_channels=num_hiddens//2**(i),
                                 out_channels=num_hiddens//2**(i-1),
                                 kernel_size=3,
                                 stride=2))
            conv_layers.append(nn.BatchNorm2d(num_hiddens//2**(i-1)))
            conv_layers.append(nn.LeakyReLU())

        self._convs = nn.Sequential(*conv_layers)
        
        if num_hiddens != embedding_dim:
            self._pre_vq_conv = nn.Conv2d(in_channels=num_hiddens, 
                                          out_channels=embedding_dim,
                                          kernel_size=1, 
                                          stride=1)

    def forward(self, x):
        
        x = self._convs(x)
        
        if num_hiddens != embedding_dim:
            x = self._pre_vq_conv(x)
        
        return x

# %%
encoder = Encoder(in_channels, num_hiddens, embedding_dim, image_size, embedding_image_size).to(device)

# %%
summary(encoder, (in_channels, image_size, image_size))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 summary(encoder, (in_channels, image_size, image_size))
#
# File /usr/local/lib/python3.8/dist-packages/torchsummary/torchsummary.py:72, in summary(model, input_size, batch_size, device)
#      68 model.apply(register_hook)
#      70 # make a forward pass
#      71 # print(x.shape)
# ---> 72 model(*x)
#      74 # remove these hooks
#      75 for h in hooks:
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[57], line 32, in Encoder.forward(self, x)
#      30 def forward(self, x):
# ---> 32     x = self._convs(x)
#      34     if num_hiddens != embedding_dim:
#      35         x = self._pre_vq_conv(x)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1212, in Module._call_impl(self, *input, **kwargs)
#    1209     bw_hook = hooks.BackwardHook(self, full_backward_hooks)
#    1210     input = bw_hook.setup_input_hook(input)
# -> 1212 result = forward_call(*input, **kwargs)
#    1213 if _global_forward_hooks or self._forward_hooks:
#    1214     for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
#
# Cell In[18], line 19, in Conv2dSame.forward(self, x)
#      14 if pad_h > 0 or pad_w > 0:
#      15     x = F.pad(
#      16         x, [pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2]
#      17     )
# ---> 19 x = F.conv2d(
#      20     x,
#      21     self.weight,
#      22     self.bias,
#      23     self.stride,
#      24     self.padding,
#      25     self.dilation,
#      26     self.groups,
#      27 )
#      29 return x
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cuda:9! (when checking argument for argument weight in method wrapper__cudnn_convolution)

# %%
class Decoder(nn.Module):
    def __init__(self, out_channels, num_hiddens, embedding_dim,  image_size, embedding_image_size):
        super(Decoder, self).__init__()
        
        if num_hiddens != embedding_dim:
            self.posq_vq_conv = nn.Conv2d(in_channels=embedding_dim,
                                     out_channels=num_hiddens,
                                     kernel_size=1, 
                                     stride=1)
        
        num_of_convs_transes = power_calc(image_size,2) - power_calc(embedding_image_size,2)
        
        conv_trans_layers = [ConvTranspose2dSame(in_channels=num_hiddens,
                                 out_channels=num_hiddens // 2,
                                 kernel_size=3,
                                 stride=2), 
                             nn.BatchNorm2d(num_hiddens // 2),
                             nn.LeakyReLU()]
        
        for i in range(power_calc(embedding_image_size,2), power_calc(image_size,2) - 1):
            
            if i != power_calc(image_size,2) - 2:
                conv_trans_layers.append(ConvTranspose2dSame(in_channels=num_hiddens//2**(i-1-power_calc(embedding_image_size,2)+2),
                                 out_channels=num_hiddens//2**(i-power_calc(embedding_image_size,2)+2),
                                 kernel_size=3,
                                 stride=2))
                conv_trans_layers.append(nn.BatchNorm2d(num_hiddens//2**(i-power_calc(embedding_image_size,2)+2)))
                conv_trans_layers.append(nn.LeakyReLU())
            else:
                conv_trans_layers.append(ConvTranspose2dSame(in_channels=num_hiddens//2**(i-1-power_calc(embedding_image_size,2)+2),
                                 out_channels=out_channels,
                                 kernel_size=3,
                                 stride=2))
                conv_trans_layers.append(nn.Sigmoid())

        self._conv_transes = nn.Sequential(*conv_trans_layers)

    def forward(self, x):
        
        if num_hiddens != embedding_dim:
            x = self.posq_vq_conv(x)
        
        x = self._conv_transes(x)
        
        return x

# %%
decoder = Decoder(in_channels, num_hiddens, 
                                embedding_dim,  image_size, embedding_image_size).to(device)

# %%
summary(decoder, (embedding_dim, embedding_image_size, embedding_image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
# ConvTranspose2dSame-1             [-1, 64, 8, 8]          73,792
#          LeakyReLU-2             [-1, 64, 8, 8]               0
# ConvTranspose2dSame-3           [-1, 32, 16, 16]          18,464
#          LeakyReLU-4           [-1, 32, 16, 16]               0
# ConvTranspose2dSame-5           [-1, 16, 32, 32]           4,624
#          LeakyReLU-6           [-1, 16, 32, 32]               0
# ConvTranspose2dSame-7            [-1, 8, 64, 64]           1,160
#          LeakyReLU-8            [-1, 8, 64, 64]               0
# ConvTranspose2dSame-9          [-1, 1, 128, 128]              73
#           Sigmoid-10          [-1, 1, 128, 128]               0
# ================================================================
# Total params: 98,113
# Trainable params: 98,113
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.19
# Params size (MB): 0.37
# Estimated Total Size (MB): 1.57
# ----------------------------------------------------------------

# %%
class VectorQuantizer(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, commitment_cost, vq_coef):
        super(VectorQuantizer, self).__init__()
        
        self._embedding_dim = embedding_dim
        self._num_embeddings = num_embeddings
        
        self._embedding = nn.Embedding(self._num_embeddings, self._embedding_dim)
        self._embedding.weight.data.uniform_(-1/self._num_embeddings, 1/self._num_embeddings)
        self._commitment_cost = commitment_cost
        self._vq_coef = vq_coef

    def forward(self, inputs):
        # convert inputs from BCHW -> BHWC
        inputs = inputs.permute(0, 2, 3, 1).contiguous()
        input_shape = inputs.shape
        
        # Flatten input
        flat_input = inputs.view(-1, self._embedding_dim)
        
        # Calculate distances
        distances = (torch.sum(flat_input**2, dim=1, keepdim=True) 
                    + torch.sum(self._embedding.weight**2, dim=1)
                    - 2 * torch.matmul(flat_input, self._embedding.weight.t()))
            
        # Encoding
        encoding_indices = torch.argmin(distances, dim=1).unsqueeze(1)
        encodings = torch.zeros(encoding_indices.shape[0], self._num_embeddings, device=inputs.device)
        encodings.scatter_(1, encoding_indices, 1)
        
        # Quantize and unflatten
        quantized = torch.matmul(encodings, self._embedding.weight).view(input_shape)
        
        # Loss
        e_latent_loss = F.mse_loss(quantized.detach(), inputs)
        q_latent_loss = F.mse_loss(quantized, inputs.detach())
        loss = self._vq_coef * q_latent_loss + self._commitment_cost * e_latent_loss
        
        quantized = inputs + (quantized - inputs).detach()
        avg_probs = torch.mean(encodings, dim=0)
        perplexity = torch.exp(-torch.sum(avg_probs * torch.log(avg_probs + 1e-10)))
        
        # convert quantized from BHWC -> BCHW
        return loss, quantized.permute(0, 3, 1, 2).contiguous(), perplexity, encodings

# %%
class VectorQuantizerEMA(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, commitment_cost, vq_coef, decay, epsilon=1e-5):
        super(VectorQuantizerEMA, self).__init__()
        
        self._embedding_dim = embedding_dim
        self._num_embeddings = num_embeddings
        
        self._embedding = nn.Embedding(self._num_embeddings, self._embedding_dim)
        self._embedding.weight.data.normal_()
        self._commitment_cost = commitment_cost
        self._vq_coef = vq_coef
        
        self.register_buffer('_ema_cluster_size', torch.zeros(num_embeddings))
        self._ema_w = nn.Parameter(torch.Tensor(num_embeddings, self._embedding_dim))
        self._ema_w.data.normal_()
        
        self._decay = decay
        self._epsilon = epsilon

    def forward(self, inputs):
        # convert inputs from BCHW -> BHWC
#         print(inputs.size())
        inputs = inputs.permute(0, 2, 3, 1).contiguous()
        input_shape = inputs.shape
        
        # Flatten input
        flat_input = inputs.view(-1, self._embedding_dim)
        
        # Calculate distances
        distances = (torch.sum(flat_input**2, dim=1, keepdim=True) 
                    + torch.sum(self._embedding.weight**2, dim=1)
                    - 2 * torch.matmul(flat_input, self._embedding.weight.t()))
            
        # Encoding
        encoding_indices = torch.argmin(distances, dim=1).unsqueeze(1)
        encodings = torch.zeros(encoding_indices.shape[0], self._num_embeddings, device=inputs.device)
        encodings.scatter_(1, encoding_indices, 1)
        
        # Quantize and unflatten
        quantized = torch.matmul(encodings, self._embedding.weight).view(input_shape)
        
        # Use EMA to update the embedding vectors
        if self.training:
            self._ema_cluster_size = self._ema_cluster_size * self._decay + \
                                     (1 - self._decay) * torch.sum(encodings, 0)
            
            # Laplace smoothing of the cluster size
            n = torch.sum(self._ema_cluster_size.data)
            self._ema_cluster_size = (
                (self._ema_cluster_size + self._epsilon)
                / (n + self._num_embeddings * self._epsilon) * n)
            
            dw = torch.matmul(encodings.t(), flat_input)
            self._ema_w = nn.Parameter(self._ema_w * self._decay + (1 - self._decay) * dw)
            
            self._embedding.weight = nn.Parameter(self._ema_w / self._ema_cluster_size.unsqueeze(1))
        
        # Straight Through Estimator
        quantized = inputs + (quantized - inputs).detach()
        avg_probs = torch.mean(encodings, dim=0)
        perplexity = torch.exp(-torch.sum(avg_probs * torch.log(avg_probs + 1e-10)))
        
        # Loss
        e_latent_loss = F.mse_loss(quantized.detach(), inputs)
        vq_loss = F.mse_loss(quantized, inputs.detach())
#         print(quantized.shape,inputs.shape)
        
        loss = self._vq_coef * vq_loss + self._commitment_cost * e_latent_loss 
        
        # convert quantized from BHWC -> BCHW
        return loss, quantized.permute(0, 3, 1, 2).contiguous(), perplexity, encoding_indices

# %%
class VQ_VAE(nn.Module):
    def __init__(self, num_channels, num_hiddens, 
                 num_embeddings, embedding_dim, image_size, embedding_image_size, commitment_cost, vq_coef, decay=0):
        super(VQ_VAE, self).__init__()
        
        self._encoder = Encoder(num_channels, num_hiddens,
                                embedding_dim, image_size, embedding_image_size,)
        
        self._pre_vq_conv = nn.Conv2d(in_channels=num_hiddens, 
                                      out_channels=embedding_dim,
                                      kernel_size=1, 
                                      stride=1)
        
        if decay > 0: 
            self._vq_vae = VectorQuantizerEMA(num_embeddings, embedding_dim, 
                                              commitment_cost, vq_coef, decay)
        else:
            self._vq_vae = VectorQuantizer(num_embeddings, embedding_dim, 
                                              commitment_cost, vq_coef)
        
        self._decoder = Decoder(num_channels, num_hiddens, 
                                embedding_dim,  image_size, embedding_image_size)

    def forward(self, x):
        z = self._encoder(x)
        loss, quantized, perplexity, _ = self._vq_vae(z)
#         print(quantized.shape)
        x_recon = self._decoder(quantized)
#         print(x_recon.shape)

        return loss, x_recon, perplexity

# %%
entropy_loss = nn.CrossEntropyLoss()

# %%
model = VQ_VAE(num_channels, num_hiddens, num_embeddings, embedding_dim, image_size, embedding_image_size, commitment_cost, vq_coef, decay).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, amsgrad=False)

# %%
class VanillaVAE(nn.Module):
    def __init__(self, in_channels, num_hiddens, image_size, embedding_image_size,
                 embedding_dim, true_percentage):
        super(VanillaVAE, self).__init__()
        
        self.num_hiddens = num_hiddens
        self.embedding_dim = embedding_dim
            
        self.encoder = Encoder(in_channels, num_hiddens, embedding_dim, image_size, embedding_image_size)
        self.decoder = Decoder(in_channels, num_hiddens, embedding_dim,  image_size, embedding_image_size)
        self.fc_mu = nn.Linear(num_hiddens*embedding_image_size**2, embedding_dim)
        self.fc_var = nn.Linear(num_hiddens*embedding_image_size**2, embedding_dim)
        
        self.decoder_input = nn.Linear(embedding_dim, num_hiddens*embedding_image_size**2)
        
        self.loss = EdgeDetectionEntropyLoss(true_percentage)
        
    def encode(self, x):
        x = self.encoder(x)
        x = torch.flatten(x, start_dim=1)
        
        mu = self.fc_mu(x)
        log_var = self.fc_var(x)
        
        return [mu, log_var]
    
    def decode(self, z):
        z = self.decoder_input(z)
        z = z.view(-1, num_hiddens, embedding_image_size, embedding_image_size)
        z = self.decoder(z)
        return z
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps * std + mu
    
    def forward(self, x, **kwargs):
        mu, log_var = self.encode(x)
        z = self.reparameterize(mu, log_var)
        return [self.decode(z), x, mu, log_var]
    
    @abstractmethod
    def loss_f(self, *args, **kwargs):
        output = args[0]
        target = args[1]
        mu = args[2]
        log_var = args[3]
        
        entropy_weight = kwargs['ENTROPY_W']
        
        kld_weight = kwargs['M_N']
        
        recons_loss = self.loss(output, target)
        
        kld_loss = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim=1), dim = 0)
        
        loss = entropy_weight * recons_loss + kld_weight * kld_loss
        return {'loss': loss, 'Reconstruction_Loss': recons_loss.detach(), 'KLD': -kld_loss.detach()}
    
    def sample (self, num_samples, current_device):
        z = torch.randn(num_samples, self.latent_dim)
        z = z.to(current_device)
        samples = self.decode(z)    
        return samples
    
    def generate(self, x, **kwargs):
        return self.forward(x)[0]

# %%
device = torch.device('cuda:8' if torch.cuda.is_available() else 'cpu')
model = VanillaVAE(in_channels, num_hiddens, image_size, embedding_image_size,
                 embedding_dim, true_percentage).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, amsgrad=False)

# %%
summary(model, (in_channels, image_size, image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#         Conv2dSame-1            [-1, 8, 32, 32]              80
#          LeakyReLU-2            [-1, 8, 32, 32]               0
#         Conv2dSame-3           [-1, 16, 16, 16]           1,168
#          LeakyReLU-4           [-1, 16, 16, 16]               0
#         Conv2dSame-5             [-1, 32, 8, 8]           4,640
#          LeakyReLU-6             [-1, 32, 8, 8]               0
#         Conv2dSame-7             [-1, 64, 4, 4]          18,496
#          LeakyReLU-8             [-1, 64, 4, 4]               0
#            Encoder-9             [-1, 64, 4, 4]               0
#            Linear-10                   [-1, 64]          65,600
#            Linear-11                   [-1, 64]          65,600
#            Linear-12                 [-1, 1024]          66,560
# ConvTranspose2dSame-13             [-1, 32, 8, 8]          18,464
#         LeakyReLU-14             [-1, 32, 8, 8]               0
# ConvTranspose2dSame-15           [-1, 16, 16, 16]           4,624
#         LeakyReLU-16           [-1, 16, 16, 16]               0
# ConvTranspose2dSame-17            [-1, 8, 32, 32]           1,160
#         LeakyReLU-18            [-1, 8, 32, 32]               0
# ConvTranspose2dSame-19            [-1, 1, 64, 64]              73
#           Sigmoid-20            [-1, 1, 64, 64]               0
#           Decoder-21            [-1, 1, 64, 64]               0
# ================================================================
# Total params: 246,465
# Trainable params: 246,465
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.56
# Params size (MB): 0.94
# Estimated Total Size (MB): 1.52
# ----------------------------------------------------------------

# %%
class EdgeDetectionLoss(nn.Module):
    def __init__(self, w1, w2, w3, data_variance):
        super(EdgeDetectionLoss, self).__init__()
        self.w1 = w1
        self.w2 = w2
        self.w3 = w3
        self.data_variance = data_variance

    def forward(self, output, target):
        loss = -target*output *self.w1 + target*(1-output) *self.w2 + output*(1-target)*self.w3
        return loss.mean() / data_variance

edge_loss = EdgeDetectionLoss(w1=1, w2=0.01, w3=0.01, data_variance=data_variance*4)

# %%
class EdgeDetectionEntropyLoss(nn.Module):
    def __init__(self, true_percentage):
        super(EdgeDetectionEntropyLoss, self).__init__()
        self.true_percentage = true_percentage

    def forward(self, output, target):
        loss = (1 - self.true_percentage) * target * torch.log(output)\
        + self.true_percentage * (1 - target) * torch.log(1 - output)
        return - loss.mean()

edge_loss = EdgeDetectionEntropyLoss(true_percentage)

# %%
model.train()
train_res_recon_error = []
train_res_vq_loss = []
train_res_perplexity = []

train_res_KLD = []

# %%
### Обучение для VAE
for i in np.arange(15000):
    (data, _) = next(iter(dataloader))
    data = data.to(device)
    optimizer.zero_grad()
    
    data_recon, x, mu, log_var = model(data)
#     print(data_recon.shape)
    model_loss = model.loss_f(data_recon, data, mu, log_var, ENTROPY_W=entropy_weight, M_N=kld_weight)
    loss = model_loss['loss']
    recon_error = model_loss['Reconstruction_Loss']
    KLD = model_loss['KLD']
    
    loss.backward()

    optimizer.step()
    
    train_res_recon_error.append(recon_error.item())
    train_res_KLD.append(KLD.item())

    if (i+1) % 25 == 0:
        print('%d iterations' % (i+1))
        print('recon_error: %.3f' % np.mean(train_res_recon_error[-100:]))
        print('KLD: %.3f' % np.mean(train_res_KLD[-100:]))
        print()

# %%
### Обучение для VQ-VAE
for i in np.arange(40000):
    (data, _) = next(iter(dataloader))
    data = data.to(device)
    optimizer.zero_grad()

    vq_loss, data_recon, perplexity = model(data)
#     print(data_recon.shape)
    recon_error = edge_loss(data_recon, data) * 10
    loss = recon_error + vq_loss
    loss.backward()

    optimizer.step()
    
    train_res_recon_error.append(recon_error.item())
    train_res_vq_loss.append(vq_loss.item())
    train_res_perplexity.append(perplexity.item())

    if (i+1) % 25 == 0:
        print('%d iterations' % (i+1))
        print('recon_error: %.3f' % np.mean(train_res_recon_error[-100:]))
        print('vq_loss: %.3f' % np.mean(train_res_vq_loss[-100:]))
        print('perplexity: %.3f' % np.mean(train_res_perplexity[-100:]))
        print()
# Out:
# 25 iterations
# recon_error: 1.125
# vq_loss: 0.049
# perplexity: 4.667
#
# 50 iterations
# recon_error: 1.088
# vq_loss: 0.034
# perplexity: 4.390
#
# 75 iterations
# recon_error: 1.058
# vq_loss: 0.034
# perplexity: 4.434
#
# 100 iterations
# recon_error: 1.034
# vq_loss: 0.038
# perplexity: 4.499
#
# 125 iterations
# recon_error: 0.987
# vq_loss: 0.040
# perplexity: 4.523
#
# 150 iterations
# recon_error: 0.956
# vq_loss: 0.051
# perplexity: 4.704
#
# 175 iterations
# recon_error: 0.936
# vq_loss: 0.060
# perplexity: 4.788
#
# 200 iterations
# recon_error: 0.924
# vq_loss: 0.065
# perplexity: 4.832
#
# 225 iterations
# recon_error: 0.918
# vq_loss: 0.070
# perplexity: 4.865
#
# 250 iterations
# recon_error: 0.914
# vq_loss: 0.074
# perplexity: 4.883
#
# 275 iterations
# recon_error: 0.911
# vq_loss: 0.079
# perplexity: 4.896
#
# 300 iterations
# recon_error: 0.909
# vq_loss: 0.083
# perplexity: 4.906
#
# 325 iterations
# recon_error: 0.908
# vq_loss: 0.087
# perplexity: 4.911
#
# 350 iterations
# recon_error: 0.907
# vq_loss: 0.091
# perplexity: 4.914
#
# 375 iterations
# recon_error: 0.907
# vq_loss: 0.094
# perplexity: 5.101
#
# 400 iterations
# recon_error: 0.904
# vq_loss: 0.096
# perplexity: 5.305
#
# 425 iterations
# recon_error: 0.899
# vq_loss: 0.098
# perplexity: 5.512
#
# 450 iterations
# recon_error: 0.894
# vq_loss: 0.099
# perplexity: 5.716
#
# 475 iterations
# recon_error: 0.889
# vq_loss: 0.101
# perplexity: 5.734
#
# 500 iterations
# recon_error: 0.889
# vq_loss: 0.102
# perplexity: 5.794
#
# 525 iterations
# recon_error: 0.885
# vq_loss: 0.101
# perplexity: 5.979
#
# 550 iterations
# recon_error: 0.879
# vq_loss: 0.101
# perplexity: 6.429
#
# 575 iterations
# recon_error: 0.874
# vq_loss: 0.102
# perplexity: 6.892
#
# 600 iterations
# recon_error: 0.866
# vq_loss: 0.103
# perplexity: 7.301
#
# 625 iterations
# recon_error: 0.863
# vq_loss: 0.104
# perplexity: 7.593
#
# 650 iterations
# recon_error: 0.862
# vq_loss: 0.105
# perplexity: 7.623
#
# 675 iterations
# recon_error: 0.861
# vq_loss: 0.105
# perplexity: 7.801
#
# 700 iterations
# recon_error: 0.857
# vq_loss: 0.104
# perplexity: 8.371
#
# 725 iterations
# recon_error: 0.848
# vq_loss: 0.102
# perplexity: 9.218
#
# 750 iterations
# recon_error: 0.840
# vq_loss: 0.099
# perplexity: 10.277
#
# 775 iterations
# recon_error: 0.831
# vq_loss: 0.097
# perplexity: 11.367
#
# 800 iterations
# recon_error: 0.824
# vq_loss: 0.096
# perplexity: 12.178
#
# 825 iterations
# recon_error: 0.818
# vq_loss: 0.095
# perplexity: 12.953
#
# 850 iterations
# recon_error: 0.815
# vq_loss: 0.095
# perplexity: 13.573
#
# 875 iterations
# recon_error: 0.809
# vq_loss: 0.094
# perplexity: 13.993
#
# 900 iterations
# recon_error: 0.806
# vq_loss: 0.094
# perplexity: 14.503
#
# 925 iterations
# recon_error: 0.803
# vq_loss: 0.094
# perplexity: 14.810
#
# 950 iterations
# recon_error: 0.801
# vq_loss: 0.095
# perplexity: 15.089
#
# 975 iterations
# recon_error: 0.800
# vq_loss: 0.095
# perplexity: 15.402
#
# 1000 iterations
# recon_error: 0.799
# vq_loss: 0.095
# perplexity: 15.507
#
# 1025 iterations
# recon_error: 0.798
# vq_loss: 0.095
# perplexity: 15.564
#
# 1050 iterations
# recon_error: 0.796
# vq_loss: 0.094
# perplexity: 15.599
#
# 1075 iterations
# recon_error: 0.794
# vq_loss: 0.094
# perplexity: 15.611
#
# 1100 iterations
# recon_error: 0.793
# vq_loss: 0.094
# perplexity: 15.640
#
# 1125 iterations
# recon_error: 0.795
# vq_loss: 0.094
# perplexity: 15.664
#
# 1150 iterations
# recon_error: 0.793
# vq_loss: 0.093
# perplexity: 15.663
#
# 1175 iterations
# recon_error: 0.793
# vq_loss: 0.093
# perplexity: 15.687
#
# 1200 iterations
# recon_error: 0.792
# vq_loss: 0.093
# perplexity: 15.665
#
# 1225 iterations
# recon_error: 0.790
# vq_loss: 0.093
# perplexity: 15.638
#
# 1250 iterations
# recon_error: 0.792
# vq_loss: 0.094
# perplexity: 15.635
#
# 1275 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 15.572
#
# 1300 iterations
# recon_error: 0.790
# vq_loss: 0.093
# perplexity: 15.534
#
# 1325 iterations
# recon_error: 0.791
# vq_loss: 0.093
# perplexity: 15.484
#
# 1350 iterations
# recon_error: 0.788
# vq_loss: 0.093
# perplexity: 15.417
#
# 1375 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 15.369
#
# 1400 iterations
# recon_error: 0.787
# vq_loss: 0.093
# perplexity: 15.315
#
# 1425 iterations
# recon_error: 0.786
# vq_loss: 0.093
# perplexity: 15.282
#
# 1450 iterations
# recon_error: 0.785
# vq_loss: 0.093
# perplexity: 15.208
#
# 1475 iterations
# recon_error: 0.785
# vq_loss: 0.093
# perplexity: 15.172
#
# 1500 iterations
# recon_error: 0.786
# vq_loss: 0.094
# perplexity: 15.145
#
# 1525 iterations
# recon_error: 0.787
# vq_loss: 0.094
# perplexity: 15.095
#
# 1550 iterations
# recon_error: 0.789
# vq_loss: 0.094
# perplexity: 15.105
#
# 1575 iterations
# recon_error: 0.790
# vq_loss: 0.094
# perplexity: 15.089
#
# 1600 iterations
# recon_error: 0.790
# vq_loss: 0.093
# perplexity: 15.053
#
# 1625 iterations
# recon_error: 0.790
# vq_loss: 0.094
# perplexity: 15.033
#
# 1650 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 14.979
#
# 1675 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 14.906
#
# 1700 iterations
# recon_error: 0.786
# vq_loss: 0.093
# perplexity: 14.865
#
# 1725 iterations
# recon_error: 0.786
# vq_loss: 0.093
# perplexity: 14.828
#
# 1750 iterations
# recon_error: 0.787
# vq_loss: 0.094
# perplexity: 14.821
#
# 1775 iterations
# recon_error: 0.788
# vq_loss: 0.094
# perplexity: 14.827
#
# 1800 iterations
# recon_error: 0.792
# vq_loss: 0.094
# perplexity: 14.824
#
# 1825 iterations
# recon_error: 0.793
# vq_loss: 0.094
# perplexity: 14.777
#
# 1850 iterations
# recon_error: 0.792
# vq_loss: 0.094
# perplexity: 14.746
#
# 1875 iterations
# recon_error: 0.792
# vq_loss: 0.094
# perplexity: 14.727
#
# 1900 iterations
# recon_error: 0.791
# vq_loss: 0.094
# perplexity: 14.670
#
# 1925 iterations
# recon_error: 0.791
# vq_loss: 0.094
# perplexity: 14.650
#
# 1950 iterations
# recon_error: 0.790
# vq_loss: 0.094
# perplexity: 14.613
#
# 1975 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 14.546
#
# 2000 iterations
# recon_error: 0.788
# vq_loss: 0.093
# perplexity: 14.531
#
# 2025 iterations
# recon_error: 0.789
# vq_loss: 0.093
# perplexity: 14.493
#
# 2050 iterations
# recon_error: 0.790
# vq_loss: 0.093
# perplexity: 14.445
#
# 2075 iterations
# recon_error: 0.792
# vq_loss: 0.093
# perplexity: 14.434
#
# 2100 iterations
# recon_error: 0.793
# vq_loss: 0.093
# perplexity: 14.376
#
# 2125 iterations
# recon_error: 0.793
# vq_loss: 0.094
# perplexity: 14.356
#
# 2150 iterations
# recon_error: 0.794
# vq_loss: 0.094
# perplexity: 14.360
#
# 2175 iterations
# recon_error: 0.794
# vq_loss: 0.094
# perplexity: 14.329
#
# 2200 iterations
# recon_error: 0.793
# vq_loss: 0.095
# perplexity: 14.325
#
# 2225 iterations
# recon_error: 0.793
# vq_loss: 0.095
# perplexity: 14.316
#
# 2250 iterations
# recon_error: 0.793
# vq_loss: 0.094
# perplexity: 14.285
#
# 2275 iterations
# recon_error: 0.792
# vq_loss: 0.094
# perplexity: 14.261
#
# 2300 iterations
# recon_error: 0.792
# vq_loss: 0.093
# perplexity: 14.244
#
# 2325 iterations
# recon_error: 0.791
# vq_loss: 0.093
# perplexity: 14.194
#
# 2350 iterations
# recon_error: 0.791
# vq_loss: 0.093
# perplexity: 14.165
#
# 2375 iterations
# recon_error: 0.792
# vq_loss: 0.093
# perplexity: 14.131
#
# 2400 iterations
# recon_error: 0.794
# vq_loss: 0.093
# perplexity: 14.099
#
# 2425 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 14.074
#
# 2450 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 14.048
#
# 2475 iterations
# recon_error: 0.794
# vq_loss: 0.093
# perplexity: 14.059
#
# 2500 iterations
# recon_error: 0.792
# vq_loss: 0.093
# perplexity: 14.059
#
# 2525 iterations
# recon_error: 0.791
# vq_loss: 0.093
# perplexity: 14.055
#
# 2550 iterations
# recon_error: 0.793
# vq_loss: 0.093
# perplexity: 14.027
#
# 2575 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.990
#
# 2600 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.952
#
# 2625 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.937
#
# 2650 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.943
#
# 2675 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.939
#
# 2700 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.927
#
# 2725 iterations
# recon_error: 0.792
# vq_loss: 0.092
# perplexity: 13.903
#
# 2750 iterations
# recon_error: 0.791
# vq_loss: 0.092
# perplexity: 13.887
#
# 2775 iterations
# recon_error: 0.790
# vq_loss: 0.092
# perplexity: 13.861
#
# 2800 iterations
# recon_error: 0.790
# vq_loss: 0.092
# perplexity: 13.857
#
# 2825 iterations
# recon_error: 0.792
# vq_loss: 0.092
# perplexity: 13.864
#
# 2850 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.849
#
# 2875 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.835
#
# 2900 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.811
#
# 2925 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.786
#
# 2950 iterations
# recon_error: 0.790
# vq_loss: 0.092
# perplexity: 13.745
#
# 2975 iterations
# recon_error: 0.790
# vq_loss: 0.092
# perplexity: 13.732
# 3000 iterations
# recon_error: 0.790
# vq_loss: 0.092
# perplexity: 13.713
#
# 3025 iterations
# recon_error: 0.792
# vq_loss: 0.092
# perplexity: 13.689
#
# 3050 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.692
#
# 3075 iterations
# recon_error: 0.793
# vq_loss: 0.092
# perplexity: 13.674
#
# 3100 iterations
# recon_error: 0.795
# vq_loss: 0.093
# perplexity: 13.680
#
# 3125 iterations
# recon_error: 0.794
# vq_loss: 0.093
# perplexity: 13.680
#
# 3150 iterations
# recon_error: 0.794
# vq_loss: 0.093
# perplexity: 13.680
#
# 3175 iterations
# recon_error: 0.796
# vq_loss: 0.093
# perplexity: 13.660
#
# 3200 iterations
# recon_error: 0.795
# vq_loss: 0.093
# perplexity: 13.617
#
# 3225 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.592
#
# 3250 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.549
#
# 3275 iterations
# recon_error: 0.792
# vq_loss: 0.092
# perplexity: 13.542
#
# 3300 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.538
#
# 3325 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.519
#
# 3350 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.512
#
# 3375 iterations
# recon_error: 0.799
# vq_loss: 0.092
# perplexity: 13.501
#
# 3400 iterations
# recon_error: 0.798
# vq_loss: 0.092
# perplexity: 13.461
#
# 3425 iterations
# recon_error: 0.796
# vq_loss: 0.092
# perplexity: 13.454
#
# 3450 iterations
# recon_error: 0.796
# vq_loss: 0.093
# perplexity: 13.447
#
# 3475 iterations
# recon_error: 0.798
# vq_loss: 0.093
# perplexity: 13.452
#
# 3500 iterations
# recon_error: 0.797
# vq_loss: 0.093
# perplexity: 13.470
#
# 3525 iterations
# recon_error: 0.798
# vq_loss: 0.093
# perplexity: 13.472
#
# 3550 iterations
# recon_error: 0.798
# vq_loss: 0.093
# perplexity: 13.470
#
# 3575 iterations
# recon_error: 0.797
# vq_loss: 0.093
# perplexity: 13.453
#
# 3600 iterations
# recon_error: 0.799
# vq_loss: 0.094
# perplexity: 13.444
#
# 3625 iterations
# recon_error: 0.799
# vq_loss: 0.093
# perplexity: 13.439
#
# 3650 iterations
# recon_error: 0.799
# vq_loss: 0.093
# perplexity: 13.431
#
# 3675 iterations
# recon_error: 0.797
# vq_loss: 0.093
# perplexity: 13.418
#
# 3700 iterations
# recon_error: 0.798
# vq_loss: 0.093
# perplexity: 13.415
#
# 3725 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.415
#
# 3750 iterations
# recon_error: 0.798
# vq_loss: 0.092
# perplexity: 13.412
#
# 3775 iterations
# recon_error: 0.799
# vq_loss: 0.092
# perplexity: 13.406
#
# 3800 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.393
#
# 3825 iterations
# recon_error: 0.798
# vq_loss: 0.092
# perplexity: 13.362
#
# 3850 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.352
#
# 3875 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.344
#
# 3900 iterations
# recon_error: 0.796
# vq_loss: 0.092
# perplexity: 13.358
#
# 3925 iterations
# recon_error: 0.796
# vq_loss: 0.092
# perplexity: 13.351
#
# 3950 iterations
# recon_error: 0.798
# vq_loss: 0.092
# perplexity: 13.338
#
# 3975 iterations
# recon_error: 0.800
# vq_loss: 0.092
# perplexity: 13.343
#
# 4000 iterations
# recon_error: 0.799
# vq_loss: 0.092
# perplexity: 13.334
#
# 4025 iterations
# recon_error: 0.799
# vq_loss: 0.093
# perplexity: 13.356
#
# 4050 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.376
#
# 4075 iterations
# recon_error: 0.796
# vq_loss: 0.092
# perplexity: 13.387
#
# 4100 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.377
#
# 4125 iterations
# recon_error: 0.794
# vq_loss: 0.092
# perplexity: 13.361
#
# 4150 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.345
#
# 4175 iterations
# recon_error: 0.798
# vq_loss: 0.092
# perplexity: 13.323
#
# 4200 iterations
# recon_error: 0.797
# vq_loss: 0.092
# perplexity: 13.306
#
# 4225 iterations
# recon_error: 0.796
# vq_loss: 0.092
# perplexity: 13.303
#
# 4250 iterations
# recon_error: 0.795
# vq_loss: 0.092
# perplexity: 13.294
#
# 4275 iterations
# recon_error: 0.796
# vq_loss: 0.091
# perplexity: 13.281
#
# 4300 iterations
# recon_error: 0.797
# vq_loss: 0.091
# perplexity: 13.310
#
# 4325 iterations
# recon_error: 0.798
# vq_loss: 0.091
# perplexity: 13.309
#
# 4350 iterations
# recon_error: 0.799
# vq_loss: 0.091
# perplexity: 13.307
#
# 4375 iterations
# recon_error: 0.797
# vq_loss: 0.091
# perplexity: 13.315
#
# 4400 iterations
# recon_error: 0.797
# vq_loss: 0.091
# perplexity: 13.299
#
# 4425 iterations
# recon_error: 0.798
# vq_loss: 0.091
# perplexity: 13.287
#
# 4450 iterations
# recon_error: 0.797
# vq_loss: 0.091
# perplexity: 13.285
#
# 4475 iterations
# recon_error: 0.798
# vq_loss: 0.091
# perplexity: 13.266
#
# 4500 iterations
# recon_error: 0.799
# vq_loss: 0.091
# perplexity: 13.242
#
# 4525 iterations
# recon_error: 0.798
# vq_loss: 0.090
# perplexity: 13.225
#
# 4550 iterations
# recon_error: 0.800
# vq_loss: 0.091
# perplexity: 13.224
#
# 4575 iterations
# recon_error: 0.800
# vq_loss: 0.091
# perplexity: 13.238
#
# 4600 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.243
#
# 4625 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.250
#
# 4650 iterations
# recon_error: 0.799
# vq_loss: 0.090
# perplexity: 13.224
#
# 4675 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.197
#
# 4700 iterations
# recon_error: 0.797
# vq_loss: 0.090
# perplexity: 13.184
#
# 4725 iterations
# recon_error: 0.798
# vq_loss: 0.090
# perplexity: 13.173
#
# 4750 iterations
# recon_error: 0.799
# vq_loss: 0.090
# perplexity: 13.182
#
# 4775 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.189
#
# 4800 iterations
# recon_error: 0.801
# vq_loss: 0.090
# perplexity: 13.179
#
# 4825 iterations
# recon_error: 0.801
# vq_loss: 0.090
# perplexity: 13.196
#
# 4850 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.194
#
# 4875 iterations
# recon_error: 0.797
# vq_loss: 0.090
# perplexity: 13.212
#
# 4900 iterations
# recon_error: 0.796
# vq_loss: 0.090
# perplexity: 13.214
#
# 4925 iterations
# recon_error: 0.798
# vq_loss: 0.090
# perplexity: 13.194
#
# 4950 iterations
# recon_error: 0.800
# vq_loss: 0.090
# perplexity: 13.174
#
# 4975 iterations
# recon_error: 0.801
# vq_loss: 0.089
# perplexity: 13.141
#
# 5000 iterations
# recon_error: 0.802
# vq_loss: 0.089
# perplexity: 13.147
#
# 5025 iterations
# recon_error: 0.801
# vq_loss: 0.089
# perplexity: 13.147
#
# 5050 iterations
# recon_error: 0.799
# vq_loss: 0.089
# perplexity: 13.149
#
# 5075 iterations
# recon_error: 0.799
# vq_loss: 0.089
# perplexity: 13.143
#
# 5100 iterations
# recon_error: 0.799
# vq_loss: 0.089
# perplexity: 13.115
#
# 5125 iterations
# recon_error: 0.797
# vq_loss: 0.089
# perplexity: 13.089
#
# 5150 iterations
# recon_error: 0.796
# vq_loss: 0.089
# perplexity: 13.089
#
# 5175 iterations
# recon_error: 0.796
# vq_loss: 0.089
# perplexity: 13.072
#
# 5200 iterations
# recon_error: 0.799
# vq_loss: 0.089
# perplexity: 13.074
#
# 5225 iterations
# recon_error: 0.800
# vq_loss: 0.089
# perplexity: 13.071
#
# 5250 iterations
# recon_error: 0.802
# vq_loss: 0.090
# perplexity: 13.060
#
# 5275 iterations
# recon_error: 0.803
# vq_loss: 0.090
# perplexity: 13.045
#
# 5300 iterations
# recon_error: 0.801
# vq_loss: 0.089
# perplexity: 13.013
#
# 5325 iterations
# recon_error: 0.801
# vq_loss: 0.089
# perplexity: 12.997
#
# 5350 iterations
# recon_error: 0.802
# vq_loss: 0.089
# perplexity: 12.971
#
# 5375 iterations
# recon_error: 0.802
# vq_loss: 0.089
# perplexity: 12.962
#
# 5400 iterations
# recon_error: 0.802
# vq_loss: 0.089
# perplexity: 12.939
#
# 5425 iterations
# recon_error: 0.805
# vq_loss: 0.089
# perplexity: 12.918
#
# 5450 iterations
# recon_error: 0.804
# vq_loss: 0.088
# perplexity: 12.890
#
# 5475 iterations
# recon_error: 0.804
# vq_loss: 0.088
# perplexity: 12.877
#
# 5500 iterations
# recon_error: 0.805
# vq_loss: 0.089
# perplexity: 12.876
#
# 5525 iterations
# recon_error: 0.802
# vq_loss: 0.088
# perplexity: 12.870
#
# 5550 iterations
# recon_error: 0.803
# vq_loss: 0.088
# perplexity: 12.867
#
# 5575 iterations
# recon_error: 0.802
# vq_loss: 0.088
# perplexity: 12.870
#
# 5600 iterations
# recon_error: 0.801
# vq_loss: 0.088
# perplexity: 12.882
#
# 5625 iterations
# recon_error: 0.801
# vq_loss: 0.088
# perplexity: 12.871
#
# 5650 iterations
# recon_error: 0.800
# vq_loss: 0.088
# perplexity: 12.877
#
# 5675 iterations
# recon_error: 0.799
# vq_loss: 0.088
# perplexity: 12.872
#
# 5700 iterations
# recon_error: 0.801
# vq_loss: 0.087
# perplexity: 12.837
#
# 5725 iterations
# recon_error: 0.802
# vq_loss: 0.087
# perplexity: 12.839
#
# 5750 iterations
# recon_error: 0.803
# vq_loss: 0.087
# perplexity: 12.818
#
# 5775 iterations
# recon_error: 0.803
# vq_loss: 0.087
# perplexity: 12.779
#
# 5800 iterations
# recon_error: 0.802
# vq_loss: 0.086
# perplexity: 12.762
#
# 5825 iterations
# recon_error: 0.801
# vq_loss: 0.086
# perplexity: 12.742
#
# 5850 iterations
# recon_error: 0.801
# vq_loss: 0.086
# perplexity: 12.724
#
# 5875 iterations
# recon_error: 0.802
# vq_loss: 0.086
# perplexity: 12.714
#
# 5900 iterations
# recon_error: 0.802
# vq_loss: 0.086
# perplexity: 12.719
#
# 5925 iterations
# recon_error: 0.803
# vq_loss: 0.086
# perplexity: 12.708
# 5950 iterations
# recon_error: 0.804
# vq_loss: 0.086
# perplexity: 12.713
#
# 5975 iterations
# recon_error: 0.804
# vq_loss: 0.086
# perplexity: 12.735
#
# 6000 iterations
# recon_error: 0.804
# vq_loss: 0.086
# perplexity: 12.728
#
# 6025 iterations
# recon_error: 0.803
# vq_loss: 0.086
# perplexity: 12.713
#
# 6050 iterations
# recon_error: 0.804
# vq_loss: 0.086
# perplexity: 12.709
#
# 6075 iterations
# recon_error: 0.805
# vq_loss: 0.086
# perplexity: 12.685
#
# 6100 iterations
# recon_error: 0.807
# vq_loss: 0.085
# perplexity: 12.675
#
# 6125 iterations
# recon_error: 0.807
# vq_loss: 0.085
# perplexity: 12.669
#
# 6150 iterations
# recon_error: 0.806
# vq_loss: 0.085
# perplexity: 12.652
#
# 6175 iterations
# recon_error: 0.805
# vq_loss: 0.084
# perplexity: 12.644
#
# 6200 iterations
# recon_error: 0.806
# vq_loss: 0.084
# perplexity: 12.637
#
# 6225 iterations
# recon_error: 0.806
# vq_loss: 0.084
# perplexity: 12.637
#
# 6250 iterations
# recon_error: 0.806
# vq_loss: 0.084
# perplexity: 12.624
#
# 6275 iterations
# recon_error: 0.805
# vq_loss: 0.084
# perplexity: 12.616
#
# 6300 iterations
# recon_error: 0.803
# vq_loss: 0.083
# perplexity: 12.607
#
# 6325 iterations
# recon_error: 0.803
# vq_loss: 0.083
# perplexity: 12.598
#
# 6350 iterations
# recon_error: 0.803
# vq_loss: 0.083
# perplexity: 12.601
#
# 6375 iterations
# recon_error: 0.806
# vq_loss: 0.083
# perplexity: 12.595
#
# 6400 iterations
# recon_error: 0.807
# vq_loss: 0.083
# perplexity: 12.584
#
# 6425 iterations
# recon_error: 0.806
# vq_loss: 0.084
# perplexity: 12.583
#
# 6450 iterations
# recon_error: 0.805
# vq_loss: 0.084
# perplexity: 12.586
#
# 6475 iterations
# recon_error: 0.803
# vq_loss: 0.084
# perplexity: 12.583
#
# 6500 iterations
# recon_error: 0.802
# vq_loss: 0.083
# perplexity: 12.593
#
# 6525 iterations
# recon_error: 0.804
# vq_loss: 0.083
# perplexity: 12.568
#
# 6550 iterations
# recon_error: 0.804
# vq_loss: 0.083
# perplexity: 12.531
#
# 6575 iterations
# recon_error: 0.805
# vq_loss: 0.083
# perplexity: 12.520
#
# 6600 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.499
#
# 6625 iterations
# recon_error: 0.806
# vq_loss: 0.083
# perplexity: 12.518
#
# 6650 iterations
# recon_error: 0.806
# vq_loss: 0.083
# perplexity: 12.542
#
# 6675 iterations
# recon_error: 0.807
# vq_loss: 0.083
# perplexity: 12.533
#
# 6700 iterations
# recon_error: 0.806
# vq_loss: 0.083
# perplexity: 12.553
#
# 6725 iterations
# recon_error: 0.804
# vq_loss: 0.083
# perplexity: 12.537
#
# 6750 iterations
# recon_error: 0.804
# vq_loss: 0.083
# perplexity: 12.513
#
# 6775 iterations
# recon_error: 0.804
# vq_loss: 0.083
# perplexity: 12.519
#
# 6800 iterations
# recon_error: 0.803
# vq_loss: 0.083
# perplexity: 12.497
#
# 6825 iterations
# recon_error: 0.805
# vq_loss: 0.083
# perplexity: 12.477
#
# 6850 iterations
# recon_error: 0.807
# vq_loss: 0.083
# perplexity: 12.469
#
# 6875 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.443
#
# 6900 iterations
# recon_error: 0.808
# vq_loss: 0.082
# perplexity: 12.427
#
# 6925 iterations
# recon_error: 0.807
# vq_loss: 0.082
# perplexity: 12.424
#
# 6950 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.432
#
# 6975 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.438
#
# 7000 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.434
#
# 7025 iterations
# recon_error: 0.807
# vq_loss: 0.082
# perplexity: 12.417
#
# 7050 iterations
# recon_error: 0.808
# vq_loss: 0.082
# perplexity: 12.385
#
# 7075 iterations
# recon_error: 0.807
# vq_loss: 0.082
# perplexity: 12.371
#
# 7100 iterations
# recon_error: 0.807
# vq_loss: 0.082
# perplexity: 12.374
#
# 7125 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.389
#
# 7150 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.381
#
# 7175 iterations
# recon_error: 0.807
# vq_loss: 0.081
# perplexity: 12.386
#
# 7200 iterations
# recon_error: 0.807
# vq_loss: 0.082
# perplexity: 12.375
#
# 7225 iterations
# recon_error: 0.806
# vq_loss: 0.082
# perplexity: 12.356
#
# 7250 iterations
# recon_error: 0.805
# vq_loss: 0.082
# perplexity: 12.378
#
# 7275 iterations
# recon_error: 0.807
# vq_loss: 0.081
# perplexity: 12.351
#
# 7300 iterations
# recon_error: 0.807
# vq_loss: 0.081
# perplexity: 12.322
#
# 7325 iterations
# recon_error: 0.808
# vq_loss: 0.081
# perplexity: 12.310
#
# 7350 iterations
# recon_error: 0.809
# vq_loss: 0.081
# perplexity: 12.276
#
# 7375 iterations
# recon_error: 0.807
# vq_loss: 0.081
# perplexity: 12.267
#
# 7400 iterations
# recon_error: 0.808
# vq_loss: 0.081
# perplexity: 12.250
#
# 7425 iterations
# recon_error: 0.808
# vq_loss: 0.081
# perplexity: 12.234
#
# 7450 iterations
# recon_error: 0.811
# vq_loss: 0.081
# perplexity: 12.185
#
# 7475 iterations
# recon_error: 0.812
# vq_loss: 0.081
# perplexity: 12.140
#
# 7500 iterations
# recon_error: 0.813
# vq_loss: 0.081
# perplexity: 12.122
#
# 7525 iterations
# recon_error: 0.815
# vq_loss: 0.080
# perplexity: 12.046
#
# 7550 iterations
# recon_error: 0.813
# vq_loss: 0.080
# perplexity: 12.012
#
# 7575 iterations
# recon_error: 0.812
# vq_loss: 0.080
# perplexity: 11.972
#
# 7600 iterations
# recon_error: 0.811
# vq_loss: 0.079
# perplexity: 11.925
#
# 7625 iterations
# recon_error: 0.810
# vq_loss: 0.079
# perplexity: 11.938
#
# 7650 iterations
# recon_error: 0.810
# vq_loss: 0.080
# perplexity: 11.959
#
# 7675 iterations
# recon_error: 0.813
# vq_loss: 0.080
# perplexity: 11.930
#
# 7700 iterations
# recon_error: 0.814
# vq_loss: 0.079
# perplexity: 11.895
#
# 7725 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.859
#
# 7750 iterations
# recon_error: 0.814
# vq_loss: 0.079
# perplexity: 11.794
#
# 7775 iterations
# recon_error: 0.811
# vq_loss: 0.079
# perplexity: 11.797
#
# 7800 iterations
# recon_error: 0.812
# vq_loss: 0.079
# perplexity: 11.797
#
# 7825 iterations
# recon_error: 0.812
# vq_loss: 0.079
# perplexity: 11.784
#
# 7850 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.789
#
# 7875 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.778
#
# 7900 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.775
#
# 7925 iterations
# recon_error: 0.815
# vq_loss: 0.079
# perplexity: 11.787
#
# 7950 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.816
#
# 7975 iterations
# recon_error: 0.816
# vq_loss: 0.079
# perplexity: 11.823
#
# 8000 iterations
# recon_error: 0.814
# vq_loss: 0.080
# perplexity: 11.857
#
# 8025 iterations
# recon_error: 0.813
# vq_loss: 0.080
# perplexity: 11.861
#
# 8050 iterations
# recon_error: 0.815
# vq_loss: 0.080
# perplexity: 11.837
#
# 8075 iterations
# recon_error: 0.813
# vq_loss: 0.079
# perplexity: 11.837
#
# 8100 iterations
# recon_error: 0.815
# vq_loss: 0.079
# perplexity: 11.827
#
# 8125 iterations
# recon_error: 0.815
# vq_loss: 0.078
# perplexity: 11.820
#
# 8150 iterations
# recon_error: 0.814
# vq_loss: 0.078
# perplexity: 11.812
#
# 8175 iterations
# recon_error: 0.814
# vq_loss: 0.078
# perplexity: 11.811
#
# 8200 iterations
# recon_error: 0.814
# vq_loss: 0.078
# perplexity: 11.784
#
# 8225 iterations
# recon_error: 0.815
# vq_loss: 0.078
# perplexity: 11.756
#
# 8250 iterations
# recon_error: 0.815
# vq_loss: 0.078
# perplexity: 11.749
#
# 8275 iterations
# recon_error: 0.815
# vq_loss: 0.078
# perplexity: 11.752
#
# 8300 iterations
# recon_error: 0.814
# vq_loss: 0.078
# perplexity: 11.736
#
# 8325 iterations
# recon_error: 0.814
# vq_loss: 0.078
# perplexity: 11.749
#
# 8350 iterations
# recon_error: 0.815
# vq_loss: 0.078
# perplexity: 11.749
#
# 8375 iterations
# recon_error: 0.816
# vq_loss: 0.078
# perplexity: 11.710
#
# 8400 iterations
# recon_error: 0.816
# vq_loss: 0.078
# perplexity: 11.707
#
# 8425 iterations
# recon_error: 0.816
# vq_loss: 0.079
# perplexity: 11.696
#
# 8450 iterations
# recon_error: 0.815
# vq_loss: 0.079
# perplexity: 11.691
#
# 8475 iterations
# recon_error: 0.816
# vq_loss: 0.078
# perplexity: 11.696
#
# 8500 iterations
# recon_error: 0.816
# vq_loss: 0.078
# perplexity: 11.697
#
# 8525 iterations
# recon_error: 0.817
# vq_loss: 0.078
# perplexity: 11.686
#
# 8550 iterations
# recon_error: 0.819
# vq_loss: 0.077
# perplexity: 11.665
#
# 8575 iterations
# recon_error: 0.816
# vq_loss: 0.078
# perplexity: 11.664
#
# 8600 iterations
# recon_error: 0.815
# vq_loss: 0.077
# perplexity: 11.664
#
# 8625 iterations
# recon_error: 0.813
# vq_loss: 0.077
# perplexity: 11.665
#
# 8650 iterations
# recon_error: 0.811
# vq_loss: 0.077
# perplexity: 11.682
#
# 8675 iterations
# recon_error: 0.813
# vq_loss: 0.077
# perplexity: 11.670
#
# 8700 iterations
# recon_error: 0.815
# vq_loss: 0.077
# perplexity: 11.655
#
# 8725 iterations
# recon_error: 0.817
# vq_loss: 0.077
# perplexity: 11.637
#
# 8750 iterations
# recon_error: 0.816
# vq_loss: 0.077
# perplexity: 11.616
#
# 8775 iterations
# recon_error: 0.817
# vq_loss: 0.077
# perplexity: 11.607
#
# 8800 iterations
# recon_error: 0.816
# vq_loss: 0.077
# perplexity: 11.593
#
# 8825 iterations
# recon_error: 0.816
# vq_loss: 0.077
# perplexity: 11.585
#
# 8850 iterations
# recon_error: 0.817
# vq_loss: 0.077
# perplexity: 11.582
#
# 8875 iterations
# recon_error: 0.817
# vq_loss: 0.077
# perplexity: 11.566
# 8900 iterations
# recon_error: 0.820
# vq_loss: 0.077
# perplexity: 11.557
#
# 8925 iterations
# recon_error: 0.819
# vq_loss: 0.077
# perplexity: 11.531
#
# 8950 iterations
# recon_error: 0.821
# vq_loss: 0.077
# perplexity: 11.506
#
# 8975 iterations
# recon_error: 0.820
# vq_loss: 0.077
# perplexity: 11.506
#
# 9000 iterations
# recon_error: 0.818
# vq_loss: 0.076
# perplexity: 11.509
#
# 9025 iterations
# recon_error: 0.817
# vq_loss: 0.077
# perplexity: 11.518
#
# 9050 iterations
# recon_error: 0.816
# vq_loss: 0.076
# perplexity: 11.512
#
# 9075 iterations
# recon_error: 0.816
# vq_loss: 0.076
# perplexity: 11.493
#
# 9100 iterations
# recon_error: 0.818
# vq_loss: 0.076
# perplexity: 11.479
#
# 9125 iterations
# recon_error: 0.820
# vq_loss: 0.076
# perplexity: 11.463
#
# 9150 iterations
# recon_error: 0.822
# vq_loss: 0.076
# perplexity: 11.438
#
# 9175 iterations
# recon_error: 0.822
# vq_loss: 0.076
# perplexity: 11.411
#
# 9200 iterations
# recon_error: 0.823
# vq_loss: 0.075
# perplexity: 11.378
#
# 9225 iterations
# recon_error: 0.821
# vq_loss: 0.075
# perplexity: 11.366
#
# 9250 iterations
# recon_error: 0.822
# vq_loss: 0.075
# perplexity: 11.373
#
# 9275 iterations
# recon_error: 0.822
# vq_loss: 0.075
# perplexity: 11.374
#
# 9300 iterations
# recon_error: 0.821
# vq_loss: 0.075
# perplexity: 11.385
#
# 9325 iterations
# recon_error: 0.821
# vq_loss: 0.075
# perplexity: 11.369
#
# 9350 iterations
# recon_error: 0.821
# vq_loss: 0.075
# perplexity: 11.338
#
# 9375 iterations
# recon_error: 0.821
# vq_loss: 0.075
# perplexity: 11.326
#
# 9400 iterations
# recon_error: 0.822
# vq_loss: 0.075
# perplexity: 11.307
#
# 9425 iterations
# recon_error: 0.821
# vq_loss: 0.074
# perplexity: 11.303
#
# 9450 iterations
# recon_error: 0.819
# vq_loss: 0.074
# perplexity: 11.318
#
# 9475 iterations
# recon_error: 0.820
# vq_loss: 0.074
# perplexity: 11.323
#
# 9500 iterations
# recon_error: 0.820
# vq_loss: 0.074
# perplexity: 11.307
#
# 9525 iterations
# recon_error: 0.820
# vq_loss: 0.074
# perplexity: 11.291
#
# 9550 iterations
# recon_error: 0.820
# vq_loss: 0.074
# perplexity: 11.286
#
# 9575 iterations
# recon_error: 0.821
# vq_loss: 0.074
# perplexity: 11.263
#
# 9600 iterations
# recon_error: 0.822
# vq_loss: 0.074
# perplexity: 11.273
#
# 9625 iterations
# recon_error: 0.823
# vq_loss: 0.075
# perplexity: 11.262
#
# 9650 iterations
# recon_error: 0.823
# vq_loss: 0.075
# perplexity: 11.239
#
# 9675 iterations
# recon_error: 0.823
# vq_loss: 0.074
# perplexity: 11.230
#
# 9700 iterations
# recon_error: 0.821
# vq_loss: 0.074
# perplexity: 11.222
#
# 9725 iterations
# recon_error: 0.822
# vq_loss: 0.073
# perplexity: 11.222
#
# 9750 iterations
# recon_error: 0.822
# vq_loss: 0.073
# perplexity: 11.230
#
# 9775 iterations
# recon_error: 0.822
# vq_loss: 0.073
# perplexity: 11.234
#
# 9800 iterations
# recon_error: 0.825
# vq_loss: 0.073
# perplexity: 11.224
#
# 9825 iterations
# recon_error: 0.826
# vq_loss: 0.073
# perplexity: 11.216
#
# 9850 iterations
# recon_error: 0.826
# vq_loss: 0.073
# perplexity: 11.193
#
# 9875 iterations
# recon_error: 0.826
# vq_loss: 0.072
# perplexity: 11.186
#
# 9900 iterations
# recon_error: 0.825
# vq_loss: 0.072
# perplexity: 11.175
#
# 9925 iterations
# recon_error: 0.823
# vq_loss: 0.072
# perplexity: 11.166
#
# 9950 iterations
# recon_error: 0.823
# vq_loss: 0.072
# perplexity: 11.149
#
# 9975 iterations
# recon_error: 0.822
# vq_loss: 0.072
# perplexity: 11.143
#
# 10000 iterations
# recon_error: 0.824
# vq_loss: 0.072
# perplexity: 11.109
#
# 10025 iterations
# recon_error: 0.824
# vq_loss: 0.072
# perplexity: 11.106
#
# 10050 iterations
# recon_error: 0.823
# vq_loss: 0.072
# perplexity: 11.107
#
# 10075 iterations
# recon_error: 0.825
# vq_loss: 0.072
# perplexity: 11.072
#
# 10100 iterations
# recon_error: 0.823
# vq_loss: 0.072
# perplexity: 11.062
#
# 10125 iterations
# recon_error: 0.825
# vq_loss: 0.072
# perplexity: 11.024
#
# 10150 iterations
# recon_error: 0.826
# vq_loss: 0.072
# perplexity: 10.990
#
# 10175 iterations
# recon_error: 0.826
# vq_loss: 0.071
# perplexity: 10.974
#
# 10200 iterations
# recon_error: 0.827
# vq_loss: 0.071
# perplexity: 10.954
#
# 10225 iterations
# recon_error: 0.827
# vq_loss: 0.071
# perplexity: 10.957
#
# 10250 iterations
# recon_error: 0.826
# vq_loss: 0.071
# perplexity: 10.953
#
# 10275 iterations
# recon_error: 0.828
# vq_loss: 0.071
# perplexity: 10.926
#
# 10300 iterations
# recon_error: 0.828
# vq_loss: 0.071
# perplexity: 10.918
#
# 10325 iterations
# recon_error: 0.829
# vq_loss: 0.071
# perplexity: 10.875
#
# 10350 iterations
# recon_error: 0.831
# vq_loss: 0.071
# perplexity: 10.852
#
# 10375 iterations
# recon_error: 0.829
# vq_loss: 0.071
# perplexity: 10.854
#
# 10400 iterations
# recon_error: 0.829
# vq_loss: 0.071
# perplexity: 10.833
#
# 10425 iterations
# recon_error: 0.830
# vq_loss: 0.072
# perplexity: 10.835
#
# 10450 iterations
# recon_error: 0.830
# vq_loss: 0.072
# perplexity: 10.847
#
# 10475 iterations
# recon_error: 0.829
# vq_loss: 0.071
# perplexity: 10.867
#
# 10500 iterations
# recon_error: 0.829
# vq_loss: 0.071
# perplexity: 10.885
#
# 10525 iterations
# recon_error: 0.827
# vq_loss: 0.071
# perplexity: 10.894
#
# 10550 iterations
# recon_error: 0.827
# vq_loss: 0.070
# perplexity: 10.883
#
# 10575 iterations
# recon_error: 0.830
# vq_loss: 0.070
# perplexity: 10.845
#
# 10600 iterations
# recon_error: 0.830
# vq_loss: 0.070
# perplexity: 10.828
#
# 10625 iterations
# recon_error: 0.830
# vq_loss: 0.070
# perplexity: 10.818
#
# 10650 iterations
# recon_error: 0.831
# vq_loss: 0.070
# perplexity: 10.812
#
# 10675 iterations
# recon_error: 0.831
# vq_loss: 0.071
# perplexity: 10.815
#
# 10700 iterations
# recon_error: 0.831
# vq_loss: 0.071
# perplexity: 10.810
#
# 10725 iterations
# recon_error: 0.831
# vq_loss: 0.071
# perplexity: 10.805
#
# 10750 iterations
# recon_error: 0.830
# vq_loss: 0.071
# perplexity: 10.798
#
# 10775 iterations
# recon_error: 0.828
# vq_loss: 0.071
# perplexity: 10.811
#
# 10800 iterations
# recon_error: 0.829
# vq_loss: 0.070
# perplexity: 10.810
#
# 10825 iterations
# recon_error: 0.827
# vq_loss: 0.070
# perplexity: 10.820
#
# 10850 iterations
# recon_error: 0.827
# vq_loss: 0.069
# perplexity: 10.815
#
# 10875 iterations
# recon_error: 0.827
# vq_loss: 0.069
# perplexity: 10.798
#
# 10900 iterations
# recon_error: 0.828
# vq_loss: 0.069
# perplexity: 10.785
#
# 10925 iterations
# recon_error: 0.830
# vq_loss: 0.069
# perplexity: 10.756
#
# 10950 iterations
# recon_error: 0.831
# vq_loss: 0.069
# perplexity: 10.736
#
# 10975 iterations
# recon_error: 0.833
# vq_loss: 0.069
# perplexity: 10.711
#
# 11000 iterations
# recon_error: 0.830
# vq_loss: 0.069
# perplexity: 10.715
#
# 11025 iterations
# recon_error: 0.831
# vq_loss: 0.069
# perplexity: 10.717
#
# 11050 iterations
# recon_error: 0.829
# vq_loss: 0.069
# perplexity: 10.729
#
# 11075 iterations
# recon_error: 0.828
# vq_loss: 0.069
# perplexity: 10.743
#
# 11100 iterations
# recon_error: 0.830
# vq_loss: 0.068
# perplexity: 10.727
#
# 11125 iterations
# recon_error: 0.830
# vq_loss: 0.068
# perplexity: 10.721
#
# 11150 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.709
#
# 11175 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.708
#
# 11200 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.710
#
# 11225 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.712
#
# 11250 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.710
#
# 11275 iterations
# recon_error: 0.830
# vq_loss: 0.068
# perplexity: 10.723
#
# 11300 iterations
# recon_error: 0.828
# vq_loss: 0.068
# perplexity: 10.733
#
# 11325 iterations
# recon_error: 0.826
# vq_loss: 0.069
# perplexity: 10.753
#
# 11350 iterations
# recon_error: 0.825
# vq_loss: 0.068
# perplexity: 10.760
#
# 11375 iterations
# recon_error: 0.826
# vq_loss: 0.068
# perplexity: 10.746
#
# 11400 iterations
# recon_error: 0.828
# vq_loss: 0.068
# perplexity: 10.726
#
# 11425 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.692
#
# 11450 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.685
#
# 11475 iterations
# recon_error: 0.833
# vq_loss: 0.068
# perplexity: 10.686
#
# 11500 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.701
#
# 11525 iterations
# recon_error: 0.832
# vq_loss: 0.069
# perplexity: 10.695
#
# 11550 iterations
# recon_error: 0.831
# vq_loss: 0.069
# perplexity: 10.690
#
# 11575 iterations
# recon_error: 0.831
# vq_loss: 0.069
# perplexity: 10.675
#
# 11600 iterations
# recon_error: 0.833
# vq_loss: 0.068
# perplexity: 10.651
#
# 11625 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.643
#
# 11650 iterations
# recon_error: 0.834
# vq_loss: 0.068
# perplexity: 10.627
#
# 11675 iterations
# recon_error: 0.833
# vq_loss: 0.067
# perplexity: 10.623
#
# 11700 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.629
#
# 11725 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.624
#
# 11750 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.614
#
# 11775 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.597
#
# 11800 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.598
# 11825 iterations
# recon_error: 0.830
# vq_loss: 0.067
# perplexity: 10.618
#
# 11850 iterations
# recon_error: 0.830
# vq_loss: 0.068
# perplexity: 10.622
#
# 11875 iterations
# recon_error: 0.830
# vq_loss: 0.068
# perplexity: 10.631
#
# 11900 iterations
# recon_error: 0.831
# vq_loss: 0.068
# perplexity: 10.614
#
# 11925 iterations
# recon_error: 0.834
# vq_loss: 0.068
# perplexity: 10.590
#
# 11950 iterations
# recon_error: 0.833
# vq_loss: 0.068
# perplexity: 10.604
#
# 11975 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.617
#
# 12000 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.621
#
# 12025 iterations
# recon_error: 0.829
# vq_loss: 0.067
# perplexity: 10.632
#
# 12050 iterations
# recon_error: 0.828
# vq_loss: 0.067
# perplexity: 10.624
#
# 12075 iterations
# recon_error: 0.828
# vq_loss: 0.067
# perplexity: 10.634
#
# 12100 iterations
# recon_error: 0.829
# vq_loss: 0.067
# perplexity: 10.633
#
# 12125 iterations
# recon_error: 0.829
# vq_loss: 0.067
# perplexity: 10.623
#
# 12150 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.611
#
# 12175 iterations
# recon_error: 0.830
# vq_loss: 0.067
# perplexity: 10.593
#
# 12200 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.576
#
# 12225 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.599
#
# 12250 iterations
# recon_error: 0.830
# vq_loss: 0.067
# perplexity: 10.611
#
# 12275 iterations
# recon_error: 0.832
# vq_loss: 0.068
# perplexity: 10.605
#
# 12300 iterations
# recon_error: 0.829
# vq_loss: 0.067
# perplexity: 10.631
#
# 12325 iterations
# recon_error: 0.829
# vq_loss: 0.067
# perplexity: 10.630
#
# 12350 iterations
# recon_error: 0.830
# vq_loss: 0.067
# perplexity: 10.614
#
# 12375 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.604
#
# 12400 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.594
#
# 12425 iterations
# recon_error: 0.834
# vq_loss: 0.067
# perplexity: 10.570
#
# 12450 iterations
# recon_error: 0.832
# vq_loss: 0.067
# perplexity: 10.592
#
# 12475 iterations
# recon_error: 0.833
# vq_loss: 0.066
# perplexity: 10.593
#
# 12500 iterations
# recon_error: 0.832
# vq_loss: 0.066
# perplexity: 10.595
#
# 12525 iterations
# recon_error: 0.831
# vq_loss: 0.067
# perplexity: 10.604
#
# 12550 iterations
# recon_error: 0.832
# vq_loss: 0.066
# perplexity: 10.589
#
# 12575 iterations
# recon_error: 0.830
# vq_loss: 0.066
# perplexity: 10.592
#
# 12600 iterations
# recon_error: 0.833
# vq_loss: 0.066
# perplexity: 10.564
#
# 12625 iterations
# recon_error: 0.833
# vq_loss: 0.066
# perplexity: 10.541
#
# 12650 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.529
#
# 12675 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.534
#
# 12700 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.546
#
# 12725 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.549
#
# 12750 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.549
#
# 12775 iterations
# recon_error: 0.837
# vq_loss: 0.066
# perplexity: 10.516
#
# 12800 iterations
# recon_error: 0.836
# vq_loss: 0.066
# perplexity: 10.497
#
# 12825 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.502
#
# 12850 iterations
# recon_error: 0.834
# vq_loss: 0.066
# perplexity: 10.507
#
# 12875 iterations
# recon_error: 0.832
# vq_loss: 0.066
# perplexity: 10.519
#
# 12900 iterations
# recon_error: 0.831
# vq_loss: 0.066
# perplexity: 10.554
#
# 12925 iterations
# recon_error: 0.831
# vq_loss: 0.066
# perplexity: 10.557
#
# 12950 iterations
# recon_error: 0.830
# vq_loss: 0.066
# perplexity: 10.579
#
# 12975 iterations
# recon_error: 0.830
# vq_loss: 0.066
# perplexity: 10.594
#
# 13000 iterations
# recon_error: 0.828
# vq_loss: 0.066
# perplexity: 10.600
#
# 13025 iterations
# recon_error: 0.831
# vq_loss: 0.065
# perplexity: 10.579
#
# 13050 iterations
# recon_error: 0.831
# vq_loss: 0.066
# perplexity: 10.573
#
# 13075 iterations
# recon_error: 0.832
# vq_loss: 0.066
# perplexity: 10.576
#
# 13100 iterations
# recon_error: 0.833
# vq_loss: 0.066
# perplexity: 10.561
#
# 13125 iterations
# recon_error: 0.831
# vq_loss: 0.066
# perplexity: 10.591
#
# 13150 iterations
# recon_error: 0.831
# vq_loss: 0.066
# perplexity: 10.581
#
# 13175 iterations
# recon_error: 0.830
# vq_loss: 0.065
# perplexity: 10.584
#
# 13200 iterations
# recon_error: 0.829
# vq_loss: 0.065
# perplexity: 10.573
#
# 13225 iterations
# recon_error: 0.830
# vq_loss: 0.065
# perplexity: 10.561
#
# 13250 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.542
#
# 13275 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.549
#
# 13300 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.551
#
# 13325 iterations
# recon_error: 0.832
# vq_loss: 0.065
# perplexity: 10.552
#
# 13350 iterations
# recon_error: 0.832
# vq_loss: 0.065
# perplexity: 10.554
#
# 13375 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.539
#
# 13400 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.543
#
# 13425 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.552
#
# 13450 iterations
# recon_error: 0.832
# vq_loss: 0.065
# perplexity: 10.565
#
# 13475 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.546
#
# 13500 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.555
#
# 13525 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.547
#
# 13550 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.524
#
# 13575 iterations
# recon_error: 0.834
# vq_loss: 0.065
# perplexity: 10.533
#
# 13600 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.504
#
# 13625 iterations
# recon_error: 0.837
# vq_loss: 0.065
# perplexity: 10.468
#
# 13650 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.503
#
# 13675 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.493
#
# 13700 iterations
# recon_error: 0.831
# vq_loss: 0.065
# perplexity: 10.504
#
# 13725 iterations
# recon_error: 0.829
# vq_loss: 0.065
# perplexity: 10.524
#
# 13750 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.456
#
# 13775 iterations
# recon_error: 0.833
# vq_loss: 0.065
# perplexity: 10.441
#
# 13800 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.407
#
# 13825 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.383
#
# 13850 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.380
#
# 13875 iterations
# recon_error: 0.838
# vq_loss: 0.064
# perplexity: 10.347
#
# 13900 iterations
# recon_error: 0.837
# vq_loss: 0.065
# perplexity: 10.354
#
# 13925 iterations
# recon_error: 0.838
# vq_loss: 0.065
# perplexity: 10.349
#
# 13950 iterations
# recon_error: 0.838
# vq_loss: 0.065
# perplexity: 10.350
#
# 13975 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.382
#
# 14000 iterations
# recon_error: 0.834
# vq_loss: 0.065
# perplexity: 10.380
#
# 14025 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.354
#
# 14050 iterations
# recon_error: 0.835
# vq_loss: 0.065
# perplexity: 10.357
#
# 14075 iterations
# recon_error: 0.838
# vq_loss: 0.065
# perplexity: 10.319
#
# 14100 iterations
# recon_error: 0.839
# vq_loss: 0.065
# perplexity: 10.317
#
# 14125 iterations
# recon_error: 0.839
# vq_loss: 0.065
# perplexity: 10.320
#
# 14150 iterations
# recon_error: 0.837
# vq_loss: 0.065
# perplexity: 10.341
#
# 14175 iterations
# recon_error: 0.836
# vq_loss: 0.065
# perplexity: 10.378
#
# 14200 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.384
#
# 14225 iterations
# recon_error: 0.834
# vq_loss: 0.064
# perplexity: 10.411
#
# 14250 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.398
#
# 14275 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.392
#
# 14300 iterations
# recon_error: 0.834
# vq_loss: 0.064
# perplexity: 10.405
#
# 14325 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.399
#
# 14350 iterations
# recon_error: 0.836
# vq_loss: 0.064
# perplexity: 10.393
#
# 14375 iterations
# recon_error: 0.837
# vq_loss: 0.064
# perplexity: 10.397
#
# 14400 iterations
# recon_error: 0.839
# vq_loss: 0.064
# perplexity: 10.362
#
# 14425 iterations
# recon_error: 0.837
# vq_loss: 0.064
# perplexity: 10.381
#
# 14450 iterations
# recon_error: 0.837
# vq_loss: 0.064
# perplexity: 10.383
#
# 14475 iterations
# recon_error: 0.839
# vq_loss: 0.064
# perplexity: 10.364
#
# 14500 iterations
# recon_error: 0.838
# vq_loss: 0.063
# perplexity: 10.380
#
# 14525 iterations
# recon_error: 0.838
# vq_loss: 0.063
# perplexity: 10.374
#
# 14550 iterations
# recon_error: 0.836
# vq_loss: 0.063
# perplexity: 10.361
#
# 14575 iterations
# recon_error: 0.835
# vq_loss: 0.063
# perplexity: 10.369
#
# 14600 iterations
# recon_error: 0.836
# vq_loss: 0.063
# perplexity: 10.349
#
# 14625 iterations
# recon_error: 0.837
# vq_loss: 0.064
# perplexity: 10.329
#
# 14650 iterations
# recon_error: 0.838
# vq_loss: 0.063
# perplexity: 10.338
#
# 14675 iterations
# recon_error: 0.841
# vq_loss: 0.064
# perplexity: 10.305
#
# 14700 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.299
# 14725 iterations
# recon_error: 0.839
# vq_loss: 0.063
# perplexity: 10.303
#
# 14750 iterations
# recon_error: 0.838
# vq_loss: 0.064
# perplexity: 10.320
#
# 14775 iterations
# recon_error: 0.834
# vq_loss: 0.064
# perplexity: 10.352
#
# 14800 iterations
# recon_error: 0.832
# vq_loss: 0.064
# perplexity: 10.378
#
# 14825 iterations
# recon_error: 0.832
# vq_loss: 0.064
# perplexity: 10.354
#
# 14850 iterations
# recon_error: 0.834
# vq_loss: 0.063
# perplexity: 10.331
#
# 14875 iterations
# recon_error: 0.837
# vq_loss: 0.063
# perplexity: 10.312
#
# 14900 iterations
# recon_error: 0.838
# vq_loss: 0.063
# perplexity: 10.293
#
# 14925 iterations
# recon_error: 0.837
# vq_loss: 0.064
# perplexity: 10.313
#
# 14950 iterations
# recon_error: 0.834
# vq_loss: 0.064
# perplexity: 10.326
#
# 14975 iterations
# recon_error: 0.834
# vq_loss: 0.064
# perplexity: 10.319
#
# 15000 iterations
# recon_error: 0.835
# vq_loss: 0.064
# perplexity: 10.300
#
# 15025 iterations
# recon_error: 0.838
# vq_loss: 0.063
# perplexity: 10.272
#
# 15050 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.267
#
# 15075 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.263
#
# 15100 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.260
#
# 15125 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.261
#
# 15150 iterations
# recon_error: 0.842
# vq_loss: 0.063
# perplexity: 10.230
#
# 15175 iterations
# recon_error: 0.841
# vq_loss: 0.064
# perplexity: 10.242
#
# 15200 iterations
# recon_error: 0.839
# vq_loss: 0.064
# perplexity: 10.256
#
# 15225 iterations
# recon_error: 0.839
# vq_loss: 0.064
# perplexity: 10.260
#
# 15250 iterations
# recon_error: 0.838
# vq_loss: 0.064
# perplexity: 10.265
#
# 15275 iterations
# recon_error: 0.840
# vq_loss: 0.064
# perplexity: 10.243
#
# 15300 iterations
# recon_error: 0.839
# vq_loss: 0.063
# perplexity: 10.240
#
# 15325 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.229
#
# 15350 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.215
#
# 15375 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.219
#
# 15400 iterations
# recon_error: 0.841
# vq_loss: 0.064
# perplexity: 10.209
#
# 15425 iterations
# recon_error: 0.840
# vq_loss: 0.064
# perplexity: 10.226
#
# 15450 iterations
# recon_error: 0.840
# vq_loss: 0.064
# perplexity: 10.233
#
# 15475 iterations
# recon_error: 0.840
# vq_loss: 0.064
# perplexity: 10.230
#
# 15500 iterations
# recon_error: 0.839
# vq_loss: 0.063
# perplexity: 10.231
#
# 15525 iterations
# recon_error: 0.839
# vq_loss: 0.063
# perplexity: 10.228
#
# 15550 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.206
#
# 15575 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.206
#
# 15600 iterations
# recon_error: 0.843
# vq_loss: 0.064
# perplexity: 10.195
#
# 15625 iterations
# recon_error: 0.843
# vq_loss: 0.064
# perplexity: 10.169
#
# 15650 iterations
# recon_error: 0.842
# vq_loss: 0.064
# perplexity: 10.184
#
# 15675 iterations
# recon_error: 0.844
# vq_loss: 0.064
# perplexity: 10.158
#
# 15700 iterations
# recon_error: 0.843
# vq_loss: 0.064
# perplexity: 10.150
#
# 15725 iterations
# recon_error: 0.842
# vq_loss: 0.064
# perplexity: 10.155
#
# 15750 iterations
# recon_error: 0.844
# vq_loss: 0.064
# perplexity: 10.113
#
# 15775 iterations
# recon_error: 0.844
# vq_loss: 0.063
# perplexity: 10.109
#
# 15800 iterations
# recon_error: 0.843
# vq_loss: 0.063
# perplexity: 10.104
#
# 15825 iterations
# recon_error: 0.845
# vq_loss: 0.062
# perplexity: 10.075
#
# 15850 iterations
# recon_error: 0.841
# vq_loss: 0.062
# perplexity: 10.121
#
# 15875 iterations
# recon_error: 0.840
# vq_loss: 0.062
# perplexity: 10.122
#
# 15900 iterations
# recon_error: 0.840
# vq_loss: 0.063
# perplexity: 10.118
#
# 15925 iterations
# recon_error: 0.839
# vq_loss: 0.063
# perplexity: 10.126
#
# 15950 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.083
#
# 15975 iterations
# recon_error: 0.841
# vq_loss: 0.063
# perplexity: 10.075
#
# 16000 iterations
# recon_error: 0.841
# vq_loss: 0.062
# perplexity: 10.058
#
# 16025 iterations
# recon_error: 0.843
# vq_loss: 0.062
# perplexity: 10.036
#
# 16050 iterations
# recon_error: 0.842
# vq_loss: 0.062
# perplexity: 10.048
#
# 16075 iterations
# recon_error: 0.840
# vq_loss: 0.062
# perplexity: 10.052
#
# 16100 iterations
# recon_error: 0.840
# vq_loss: 0.062
# perplexity: 10.054
#
# 16125 iterations
# recon_error: 0.839
# vq_loss: 0.061
# perplexity: 10.059
#
# 16150 iterations
# recon_error: 0.839
# vq_loss: 0.061
# perplexity: 10.020
#
# 16175 iterations
# recon_error: 0.841
# vq_loss: 0.061
# perplexity: 9.990
#
# 16200 iterations
# recon_error: 0.841
# vq_loss: 0.060
# perplexity: 9.961
#
# 16225 iterations
# recon_error: 0.842
# vq_loss: 0.060
# perplexity: 9.939
#
# 16250 iterations
# recon_error: 0.840
# vq_loss: 0.060
# perplexity: 9.957
#
# 16275 iterations
# recon_error: 0.840
# vq_loss: 0.059
# perplexity: 9.912
#
# 16300 iterations
# recon_error: 0.841
# vq_loss: 0.059
# perplexity: 9.880
#
# 16325 iterations
# recon_error: 0.841
# vq_loss: 0.058
# perplexity: 9.831
#
# 16350 iterations
# recon_error: 0.842
# vq_loss: 0.057
# perplexity: 9.783
#
# 16375 iterations
# recon_error: 0.842
# vq_loss: 0.057
# perplexity: 9.762
#
# 16400 iterations
# recon_error: 0.843
# vq_loss: 0.057
# perplexity: 9.724
#
# 16425 iterations
# recon_error: 0.845
# vq_loss: 0.057
# perplexity: 9.689
#
# 16450 iterations
# recon_error: 0.846
# vq_loss: 0.057
# perplexity: 9.636
#
# 16475 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.606
#
# 16500 iterations
# recon_error: 0.844
# vq_loss: 0.056
# perplexity: 9.594
#
# 16525 iterations
# recon_error: 0.843
# vq_loss: 0.056
# perplexity: 9.585
#
# 16550 iterations
# recon_error: 0.844
# vq_loss: 0.056
# perplexity: 9.564
#
# 16575 iterations
# recon_error: 0.844
# vq_loss: 0.056
# perplexity: 9.567
#
# 16600 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.534
#
# 16625 iterations
# recon_error: 0.847
# vq_loss: 0.056
# perplexity: 9.500
#
# 16650 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.485
#
# 16675 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.449
#
# 16700 iterations
# recon_error: 0.847
# vq_loss: 0.056
# perplexity: 9.430
#
# 16725 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.416
#
# 16750 iterations
# recon_error: 0.847
# vq_loss: 0.056
# perplexity: 9.374
#
# 16775 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.359
#
# 16800 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.340
#
# 16825 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.310
#
# 16850 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.301
#
# 16875 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.286
#
# 16900 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.277
#
# 16925 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.270
#
# 16950 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.282
#
# 16975 iterations
# recon_error: 0.845
# vq_loss: 0.056
# perplexity: 9.254
#
# 17000 iterations
# recon_error: 0.844
# vq_loss: 0.056
# perplexity: 9.228
#
# 17025 iterations
# recon_error: 0.844
# vq_loss: 0.056
# perplexity: 9.210
#
# 17050 iterations
# recon_error: 0.846
# vq_loss: 0.056
# perplexity: 9.179
#
# 17075 iterations
# recon_error: 0.847
# vq_loss: 0.056
# perplexity: 9.174
#
# 17100 iterations
# recon_error: 0.849
# vq_loss: 0.057
# perplexity: 9.159
#
# 17125 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.174
#
# 17150 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.174
#
# 17175 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.162
#
# 17200 iterations
# recon_error: 0.845
# vq_loss: 0.057
# perplexity: 9.175
#
# 17225 iterations
# recon_error: 0.846
# vq_loss: 0.057
# perplexity: 9.154
#
# 17250 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.130
#
# 17275 iterations
# recon_error: 0.846
# vq_loss: 0.057
# perplexity: 9.120
#
# 17300 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.089
#
# 17325 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.073
#
# 17350 iterations
# recon_error: 0.845
# vq_loss: 0.057
# perplexity: 9.094
#
# 17375 iterations
# recon_error: 0.848
# vq_loss: 0.057
# perplexity: 9.052
#
# 17400 iterations
# recon_error: 0.847
# vq_loss: 0.057
# perplexity: 9.077
#
# 17425 iterations
# recon_error: 0.846
# vq_loss: 0.057
# perplexity: 9.083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 3
#       1 ### Обучение для VQ-VAE
#       2 for i in np.arange(40000):
# ----> 3     (data, _) = next(iter(dataloader))
#       4     data = data.to(device)
#       5     optimizer.zero_grad()
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# Cell In[4], line 13, in EdgesDataset.__getitem__(self, index)
#      11 img = img[32:-32, 32:-32]
#      12 img = cv2.resize(img, self.dim)
# ---> 13 img = cv2.Canny(img,150,250)
#      14 # you need to convert img from np.array to torch.tensor
#      15 # this has to be done CAREFULLY!
#      16 sample = transforms.ToTensor()(img)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), f'VQ_VAE_models/VQ_VAE_im{image_size}x{image_size}_emb{embedding_image_size}x{embedding_image_size}-{embedding_dim}-{num_embeddings}_hid{num_hiddens}_edge.pt')

# %%
from scipy.signal import savgol_filter

# %%
train_res_recon_error_smooth = savgol_filter(train_res_recon_error, 201, 7)
train_res_vq_loss_smooth = savgol_filter(train_res_vq_loss, 201, 7)
train_res_perplexity_smooth = savgol_filter(train_res_perplexity, 201, 7)

# %%
f = plt.figure(figsize=(16,8))
ax = f.add_subplot(1,3,1)
ax.plot(train_res_recon_error_smooth)
ax.set_yscale('log')
ax.set_title('Smoothed NMSE.')
ax.set_xlabel('iteration')

ax = f.add_subplot(1,3,2)
ax.plot(train_res_vq_loss_smooth)
ax.set_title('Smoothed vq_loss.')
ax.set_xlabel('iteration')

ax = f.add_subplot(1,3,3)
ax.plot(train_res_perplexity_smooth)
ax.set_title('Smoothed Average codebook usage (perplexity).')
ax.set_xlabel('iteration')
# Out:
# Text(0.5, 0, 'iteration')

# %%
os.chdir('C:/Users/user/')

# %%
import cv2

# %%
iter_dl = iter(dataloader)
x = next(iter_dl)
x = x[0]
_, data_recon, _ = model(x.to(device))
# data_recon, _, _, _ = model(x.to(device))

fig = plt.figure(figsize=(25, 16))
for i in np.arange(0,32):
    
    ax = fig.add_subplot(4, 8, i*2 + 1, xticks=[], yticks=[])
    img = x[i].numpy().transpose(1,2,0)
    plt.imshow(img)
    
    ax = fig.add_subplot(4, 8, i*2 + 2, xticks=[], yticks=[])
    img = (data_recon[i].cpu().detach().numpy().transpose(1,2,0)-0.23).round()
    plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 10
#       7 fig = plt.figure(figsize=(25, 16))
#       8 for i in np.arange(0,32):
# ---> 10     ax = fig.add_subplot(4, 8, i*2 + 1, xticks=[], yticks=[])
#      11     img = x[i].numpy().transpose(1,2,0)
#      12     plt.imshow(img)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:644, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     642 else:
#     643     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 644     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     645 if self._position.width < 0 or self._position.height < 0:
#     646     raise ValueError('Width and height specified must be non-negative')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 32, not 33

# %%
_, data_recon, _ = model(x.to(device))
img = (data_recon[7].cpu().detach().numpy().transpose(1,2,0)-0.25).round()
plt.imshow(img)
# print(img)
